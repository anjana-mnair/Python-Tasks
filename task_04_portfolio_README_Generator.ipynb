# %% [markdown]
# <a href="https://colab.research.google.com/github/anjana-mnair/Python-Tasks/blob/main/task_04_portfolio_README_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("Enter your name:")
degree=input("Enter your degree:")
skills=input("Enter your skills:")
hobbies=input("Enter your hobbies:")
career_goal=input("Enter youe career goal:")
print("\n#"+name)
print()
print("## about me")
print(f"I am a{degree}student.")
print()
print("##skills")
print(skills)
print()
print("##Hobbies")
print(hobbies)
print()
print("##Career Goal")
print(career_goal)
# Out:
# Enter your name:ANJANA M NAIR
# Enter your degree:BCA
# Enter your skills:PROBLEM SOLVING
# Enter your hobbies:LISENING MUSIC,DRAWING
# Enter youe career goal:FULL STACK AI  DEVELOPER
#
# #ANJANA M NAIR
#
# ## about me
# I am aBCAstudent.
#
# ##skills
# PROBLEM SOLVING
#
# ##Hobbies
# LISENING MUSIC,DRAWING
#
# ##Career Goal
# FULL STACK AI  DEVELOPER
