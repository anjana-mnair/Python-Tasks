# %% [markdown]
# <a href="https://colab.research.google.com/github/anjana-mnair/Python-Tasks/blob/main/Task_02_My_Digital_Identity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 name=input("Name: ")
 age=int(input("Age:  "))
 department=input("Department: ")
 cgpa=float(input("CGPA: "))
 blood_group=input("Bloood Group: ")
 email=input("Email: ")
 phone=input("Phone: ")
 print("\n"+"=" * 40)
 print("        STUDENT PROFILE")
 print("=" * 40)
 print(f"Name:{name}")
 print(f"Age:{age}")
 print(f"Department:{department}")
 print(f"CGPA:{cgpa}")
 print(f"Blood Group:{blood_group}")
 print(f"Email:{email}")
 print(f"Phone:{phone}")
print("="*40)
# Out:
# Name: ANJANA M NAIR
# Age:  17
# Department: BCA
# CGPA: 8.5
# Bloood Group: A+ve
# Email: anjanamnair2009@gmail.com
# Phone: 8848856945
#
# ========================================
#         STUDENT PROFILE
# ========================================
# Name:ANJANA M NAIR
# Age:17
# Department:BCA
# CGPA:8.5
# Blood Group:A+ve
# Email:anjanamnair2009@gmail.com
# Phone:8848856945
# ========================================
