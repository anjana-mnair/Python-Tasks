# %% [markdown]
# <a href="https://colab.research.google.com/github/anjana-mnair/Python-Tasks/blob/main/Task_04_Smart_Bio_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("Enter your name:" )
degree=input("Enter your degree:")
skills=input("Enter your skills:")
career_goal=input("Enter your career goals:")
print("\nLinkedIn Bio:")
print(f"Hi,I am {name}, a {degree} student interseted in tecnology. my skills include {skills}.my career goal is to become a {career_goal}.")
print("\n Github Bio :")
print(f"{name}|{degree}student|{skills}|Aspiring {career_goal}")
print("\nTwitter Bio:")
print(f"{degree} student|Learning {skills}|Future {career_goal}")
print("\nPersonal Website Bio:")
print(f"Welcome!I am {name},a {degree} student passionate about technology and interested in becoming a {career_goal}.")
# Out:
# Enter your name:Anjana.M.Nair
# Enter your degree:BCA
# Enter your skills:Problem solving
# Enter your career goals:Full Stack AI Developer
#
# LinkedIn Bio:
# Hi,I am Anjana.M.Nair, a BCA student interseted in tecnology. my skills include Problem solving.my career goal is to become a Full Stack AI Developer.
#
#  Github Bio :
# Anjana.M.Nair|BCAstudent|Problem solving|Aspiring Full Stack AI Developer
#
# Twitter Bio:
# BCA student|Learning Problem solving|Future Full Stack AI Developer
#
# Personal Website Bio:
# Welcome!I am Anjana.M.Nair,a BCA student passionate about technology and interested in becoming a Full Stack AI Developer.
