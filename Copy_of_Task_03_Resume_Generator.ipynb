# %% [markdown]
# <a href="https://colab.research.google.com/github/anjana-mnair/Python-Tasks/blob/main/Copy_of_Task_03_Resume_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("Full Name: ")
education=input("Education:")
skills=input("Skills(comma separated):")
projects=input("Projects(comma separated):")
language=input("Languages known:")

print("\n"+"="*45)
print(f"{name.upper():^45}")
print("="*45)
print("\nEDUCATION")
print("-"*45)
print(education)
print("\nSKILLS")
print("-"*45)
for s in skills.split(","):
    print(f" . {s.strip()}")
print("\nPROJECTS")
print("-"*45)
for p in projects.split(","):
  print(f" .{p.strip()}")
print("\nLANGUAGES")
print("-" *45)
print(languages)
print("="*45)
# Out:
# Full Name: ANJANA M NAIR
# Education:PLUS TWO
# Skills(comma separated):PROBLEM SOLVING
# Projects(comma separated):MY DIGITAL IDENTITY,STUDENT PROFILE MANAGER
# Languages known:ENGLISH,MALAYALAM
#
# ...
#                 ANJANA M NAIR
# ...
#
# EDUCATION
# ---------------------------------------------
# PLUS TWO
#
# SKILLS
# ---------------------------------------------
#  . PROBLEM SOLVING
#
# PROJECTS
# ---------------------------------------------
#  .MY DIGITAL IDENTITY
#  .STUDENT PROFILE MANAGER
#
# LANGUAGES
# ---------------------------------------------
# ENGLISH,MALAYALAM
# ...
