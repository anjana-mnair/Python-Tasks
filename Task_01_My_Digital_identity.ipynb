# %% [markdown]
# <a href="https://colab.research.google.com/github/anjana-mnair/Python-Tasks/blob/main/Task_01_My_Digital_identity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="Anjana.M.Nair"
reg_no="JSOFT26008"
department="BCA"
semester=1
skills="problem solving"
hobbies="lisening music,writing,drawing"
dream_company="Google"
github="https://github.com/anjana-mnair"
linkedin="https://www.linkedin.com/in/anjana-m-nair-605a9642a/"
career_goal= "skilled full stack developer"
print("="*40)
print("      MY DIGITAL IDENTITY")
print("="*40)
print(f"Name:{name}")
print(f"Reg  Number:{reg_no}")
print(f"Department:{department}")
print(f"Semester:{semester}")
print(f"Skills:{skills}")
print(f"Hobbies:{hobbies}")
print(f"Dream company:{dream_company}")
print(f"Github:{github}")
print(f"Linkedin :{linkedin}")
print(f"Career Goal:{career_goal}")
print("="*40)
# Out:
# ...
#       MY DIGITAL IDENTITY
# ...
# Name:Anjana.M.Nair
# Reg  Number:JSOFT26008
# Department:BCA
# Semester:1
# Skills:problem solving
# Hobbies:lisening music,writing,drawing
# Dream company:Google
# Github:https://github.com/anjana-mnair
# Linkedin :https://www.linkedin.com/in/anjana-m-nair-605a9642a/
# Career Goal:skilled full stack developer
# ...
